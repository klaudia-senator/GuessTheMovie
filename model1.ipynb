# %% [markdown]
# <a href="https://colab.research.google.com/github/klaudia-senator/GuessTheMovie/blob/master/model1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python /content/unet/test.py
# Out:
# Wejście: torch.Size([1, 3, 720, 1280])
# Wyjście: torch.Size([1, 6, 720, 1280])

# %%
# !unzip unet.zip -d unet
# Out:
# Archive:  unet.zip
#    creating: unet/unet/
#    creating: unet/unet/images/
#    creating: unet/unet/train_labeled/
#   inflating: unet/unet/visualize.py
#   inflating: unet/unet/test.py
#   inflating: unet/unet/dataset.py
#   inflating: unet/__MACOSX/unet/._dataset.py
#   inflating: unet/unet/split_dataset.py
#    creating: unet/unet/model/
#   inflating: unet/unet/train.py
#    creating: unet/unet/train/
#    creating: unet/unet/pool/
#    creating: unet/unet/masks/
#    creating: unet/unet/val/
#   inflating: unet/unet/images/zdjecia-kamera1_frame_04467.jpg
#   inflating: unet/unet/images/zdjecia-kamera1_frame_04261.jpg
#   inflating: unet/unet/images/zdjecia-kamera1_frame_00563.jpg
#   inflating: unet/unet/images/zdjecia-kamera1_frame_01654.jpg
#   inflating: unet/unet/images/zdjecia-kamera1_frame_04472.jpg
#   inflating: unet/unet/images/zdjecia-kamera1_frame_01287.jpg
#   inflating: unet/unet/images/zdjecia-kamera1_frame_04713.jpg
# ...

# %%
# %cd /content/unet
# Out:
# /content/unet

# %%
# !python train.py
# Out:
# 🌀 Epoka 1/20
#   🔹 Batch 5/21 - Loss: 1.3671
#   🔹 Batch 10/21 - Loss: 0.9673
#   🔹 Batch 15/21 - Loss: 0.7155
#   🔹 Batch 20/21 - Loss: 0.7241
#   🔹 Batch 21/21 - Loss: 0.5652
# ✅ Epoka 1 zakończona | Średni loss: 1.0729 | ⏱ Czas: 44.08s
#            -> Val Loss: 0.9329
#            ✅ Zapisano nowy najlepszy model!
#
# 🌀 Epoka 2/20
#   🔹 Batch 5/21 - Loss: 0.4808
#   🔹 Batch 10/21 - Loss: 0.4557
#   🔹 Batch 15/21 - Loss: 0.4571
#   🔹 Batch 20/21 - Loss: 0.4581
#   🔹 Batch 21/21 - Loss: 0.4272
# ✅ Epoka 2 zakończona | Średni loss: 0.4730 | ⏱ Czas: 45.80s
#            -> Val Loss: 0.4407
#            ✅ Zapisano nowy najlepszy model!
#
# 🌀 Epoka 3/20
#   🔹 Batch 5/21 - Loss: 0.3621
#   🔹 Batch 10/21 - Loss: 0.3130
#   🔹 Batch 15/21 - Loss: 0.3489
#   🔹 Batch 20/21 - Loss: 0.3310
#   🔹 Batch 21/21 - Loss: 0.2532
# ✅ Epoka 3 zakończona | Średni loss: 0.3444 | ⏱ Czas: 45.02s
#            -> Val Loss: 0.2903
#            ✅ Zapisano nowy najlepszy model!
#
# 🌀 Epoka 4/20
# ...

# %%
# !python visualize.py
# Out:
# Traceback (most recent call last):
#   File "/content/unet/visualize.py", line 5, in <module>
#     from dataset import UNetDataset, train_transform
# ImportError: cannot import name 'UNetDataset' from 'dataset' (/content/unet/dataset.py)
